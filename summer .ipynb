# %%
import pandas as pd

# %%
df=pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# # 1. In how many cities Summer Olympics is held so far?

# %%
df["City"].nunique()
# Out:
# 22

# %% [markdown]
# ## 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
df[df["Medal"] == "Gold"].Sport.value_counts().head()
# Out:
# Aquatics      1421
# Athletics     1215
# Rowing         890
# Gymnastics     820
# Fencing        552
# Name: Sport, dtype: int64

# %%
df[df["Medal"] == "Gold"].Sport.value_counts().head().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3. Which sport is having most number of medals so far? (Top 5)

# %%
df.Sport.value_counts().head()
# Out:
# Aquatics      4170
# Athletics     3638
# Rowing        2667
# Gymnastics    2307
# Fencing       1613
# Name: Sport, dtype: int64

# %%
df.Sport.value_counts().head().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4. Which player has won most number of medals? (Top 5)

# %%
df.Athlete.value_counts().head()
# Out:
# PHELPS, Michael       22
# LATYNINA, Larisa      18
# ANDRIANOV, Nikolay    15
# ONO, Takashi          13
# SHAKHLIN, Boris       13
# Name: Athlete, dtype: int64

# %%
df.Athlete.value_counts().head().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
df[df["Medal"] == "Gold"].Athlete.value_counts().head()
# Out:
# PHELPS, Michael     18
# NURMI, Paavo         9
# LEWIS, Carl          9
# LATYNINA, Larisa     9
# SPITZ, Mark          9
# Name: Athlete, dtype: int64

# %%
df[df["Medal"] == "Gold"].Athlete.value_counts().head().plot(x='Athlete', y="Medal",kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 6. In which year India won first Gold Medal in Summer Olympics?

# %%
df2=df[df.Medal=="Gold"]
min((df2[df2.Country=="IND"]).Year)
# Out:
# 1928

# %% [markdown]
# ## 7. Which event is most popular in terms on number of player? (Top 5)

# %%
df["Event"].value_counts().head()
# Out:
# Football            1497
# Hockey              1422
# Team Competition    1147
# Basketball          1012
# Handball             973
# Name: Event, dtype: int64

# %%
df["Event"].value_counts().head().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
df2=df[df.Medal == "Gold"]
df2[df2.Gender == "Women"].Sport.value_counts().head()
# Out:
# Aquatics      589
# Athletics     389
# Gymnastics    268
# Rowing        217
# Volleyball    166
# Name: Sport, dtype: int64

# %%
df2[df2.Gender == "Women"].Sport.value_counts().head().plot()
# Out:
# <AxesSubplot:>
